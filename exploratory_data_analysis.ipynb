# %%
import pandas as pd
import sqlite3

db = sqlite3.connect('database.sqlite')
cursor = db.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
#for table_name in tables:
    #print(table_name)
    #table_name = table_name[0]

    #table = pd.read_sql_query("SELECT * from %s" % table_name, db)
    #table.to_csv(table_name + '.csv', index_label='index')
table = pd.read_sql_query("SELECT * from BoardGames", db)
#table.to_csv('board_games.csv', index_label='index')
#print(table[0:3])
head = table.head()


for col in table.columns: 
    print(col) 
cursor.close()
db.close()
# Out:
# row_names
# game.id
# game.type
# details.description
# details.image
# details.maxplayers
# details.maxplaytime
# details.minage
# details.minplayers
# details.minplaytime
# details.name
# details.playingtime
# details.thumbnail
# details.yearpublished
# attributes.boardgameartist
# attributes.boardgamecategory
# attributes.boardgamecompilation
# attributes.boardgamedesigner
# attributes.boardgameexpansion
# attributes.boardgamefamily
# attributes.boardgameimplementation
# attributes.boardgameintegration
# attributes.boardgamemechanic
# attributes.boardgamepublisher
# attributes.total
# stats.average
# stats.averageweight
# stats.bayesaverage
# stats.family.abstracts.bayesaverage
# stats.family.abstracts.pos
# stats.family.cgs.bayesaverage
# stats.family.cgs.pos
# stats.family.childrensgames.bayesaverage
# stats.family.childrensgames.pos
# stats.family.familygames.bayesaverage
# stats.family.familygames.pos
# stats.family.partygames.bayesaverage
# stats.family.partygames.pos
# ...

# %%
rslt_df = table.loc[(table['stats.numweights'] > 3) & (~pd.isna(table['polls.suggested_playerage']))] 
#kids_df = rslt_df[rslt_df['polls.suggested_playerage'].astype('int') < 8]
kids_df = rslt_df[rslt_df['polls.suggested_playerage'].astype('int') < 8]
len(rslt_df)
# Out:
# 11356

# %%
plt.plot(rslt_df['stats.averageweight'], rslt_df['stats.average'],'.', color = '#0097a7')
#plt.plot(kids_df['stats.averageweight'], kids_df['stats.average'],'.', color = '#ffab40')
plt.plot(3.8,8.9, '.', color='k')
plt.ylim(2,10)
#plt.xlim(1,5)
plt.axis('off')
#plt.savefig('kids_game_ratings.png', transparent=True, dpi=200)
plt.savefig('game_ratings.png', transparent=True, dpi=200)
plt.show()

# %%
plt.plot(rslt_df['stats.averageweight'], rslt_df['stats.numcomments'],'.')
plt.plot(kids_df['stats.averageweight'], kids_df['stats.numcomments'],'.')
plt.gca().set_yscale('log')

# %%
rslt_df[rslt_df['game.id']=='174430']
# Out:
#       row_names game.id  game.type  \
# 75624     75625  174430  boardgame
#
#                                      details.description  \
# 75624  Gloomhaven is a game of Euro-inspired tactical...
#
#                                       details.image  details.maxplayers  \
# 75624  //cf.geekdo-images.com/images/pic2437871.jpg                 4.0
#
#        details.maxplaytime  details.minage  details.minplayers  \
# 75624                150.0            12.0                 1.0
#
#        details.minplaytime  ... stats.family.arcade.bayesaverage  \
# 75624                 90.0  ...                              NaN
#
#        stats.family.arcade.pos stats.family.atarist.bayesaverage  \
# 75624                      NaN                               NaN
#
#        stats.family.atarist.pos stats.family.commodore64.bayesaverage  \
# 75624                       NaN                                   NaN
#
#       stats.family.commodore64.pos stats.subtype.rpgitem.bayesaverage  \
# ...
